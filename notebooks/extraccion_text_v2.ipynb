# %%
from sina.ollama.extract_flyer_text import extract_text

# %% [markdown]
# ## Default

# %% [markdown]
# ### Casa ley

# %%
extract_text(
    supermarket="casa_ley",
    city="hermosillo",
    date="2026-03-05"
)
# Out:
# ⏳ Batch 1/21 (1 imágenes)...
# ✅ Respondió en 32.90s
#   → 21 productos encontrados
#
# ⏳ Batch 2/21 (1 imágenes)...
# ✅ Respondió en 21.96s
#   → 14 productos encontrados
#
# ⏳ Batch 3/21 (1 imágenes)...
# ✅ Respondió en 60.66s
#   → 6 productos encontrados
#
# ⏳ Batch 4/21 (1 imágenes)...
# ✅ Respondió en 10.61s
#
# ⏳ Batch 5/21 (1 imágenes)...
# ✅ Respondió en 13.43s
#
# ⏳ Batch 6/21 (1 imágenes)...
# ✅ Respondió en 29.85s
#   → 15 productos encontrados
#
# ⏳ Batch 7/21 (1 imágenes)...
# ✅ Respondió en 37.09s
#   → 3 productos encontrados
#
# ⏳ Batch 8/21 (1 imágenes)...
# ✅ Respondió en 40.42s
#
# ⏳ Batch 9/21 (1 imágenes)...
# ✅ Respondió en 44.69s
#   → 14 productos encontrados
#
# ⏳ Batch 10/21 (1 imágenes)...
# ✅ Respondió en 18.83s
#   → 4 productos encontrados
#
# ⏳ Batch 11/21 (1 imágenes)...
# ✅ Respondió en 30.40s
#   → 15 productos encontrados
#
# ⏳ Batch 12/21 (1 imágenes)...
# ✅ Respondió en 22.51s
#   → 4 productos encontrados
#
# ⏳ Batch 13/21 (1 imágenes)...
# ...

# %% [markdown]
# ### Abarrey
